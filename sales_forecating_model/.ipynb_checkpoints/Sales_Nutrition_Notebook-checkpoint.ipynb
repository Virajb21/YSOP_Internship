# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
# plt.style.use('ggplot')
# plt.style.use('fivethirtyeight')
from neuralprophet import NeuralProphet

# %%
df = pd.read_excel('../Downloads/ExtendedDataset.xlsb',engine='pyxlsb')
df_backup = df

# %%
df.head(5)
# Out:
#         FY    Inv Date   Prod Code  Qty in MT  Basic Turnover Rs Lacs  \
# 0  2020-21  01.04.2020  ABCD101001       27.0                 6.27426
# 1  2020-21  01.04.2020  ABCD103001       12.0                 2.96004
# 2  2020-21  01.04.2020  ABCD101001       10.0                 2.32380
# 3  2020-21  01.04.2020  ABCD103001       13.0                 3.20671
# 4  2020-21  01.04.2020  ABCD103001       13.0                 3.20671
#
#    Customer     Material Desc UOM                Customer Name  \
# 0  ABCD1734  ABC Nutrition 12  MT          KISAN AGRO SERVICES
# 1  ABCD1503  ABC Nutrition 21  MT  SHRINATH KRUSHI SEVA KENDRA
# 2  ABCD1503  ABC Nutrition 12  MT  SHRINATH KRUSHI SEVA KENDRA
# 3  ABCD1537  ABC Nutrition 21  MT      CHAITANYA AGREE TRADERS
# 4  ABCD1419  ABC Nutrition 21  MT     KAMAL KRISHI SEVA KENDRA
#
#                  City    Taluka District        State  Day Month
# 0     PAPRI (SOLAPUR)     MOHOL  Solapur  Maharashtra    1   Apr
# 1  TALEGAON DHAMDHERE    SHIRUR     Pune  Maharashtra    1   Apr
# 2  TALEGAON DHAMDHERE    SHIRUR     Pune  Maharashtra    1   Apr
# 3              OTURE)    JUNNER     Pune  Maharashtra    1   Apr
# 4    NANDGAON(MANMAD)  NANDGAON   Nashik  Maharashtra    1   Apr

# %%
df = df.rename(columns = {'Inv Date': 'Inv_Date', 'Prod Code': 'Prod_Code', 'Material Desc' : 'Material_Desc', 'Qty in MT': 'QtyInMt', 'Basic Turnover Rs Lacs': 'BasicTurnoverInLacs', 'Per Unit Price (Rs/MT)': 'PerUnitPrice'})

# %%
df = df.drop(['FY','Customer Name','Day','Month','UOM'],axis=1)

# %%
df[['Taluka','District','State']] = df[['Taluka','District','State']].astype(str)
df[['Taluka','District','State']] = df[['Taluka','District','State']].apply(lambda x: x.str.capitalize())
print(df['Taluka'].head)
# Out:
# <bound method NDFrame.head of 0            Mohol
# 1           Shirur
# 2           Shirur
# 3           Junner
# 4         Nandgaon
#             ...
# 188690        Akot
# 188691        Akot
# 188692        Akot
# 188693    Jamnagar
# 188694      Bhokar
# Name: Taluka, Length: 188695, dtype: object>

# %%
df['City'] = df['City'].astype(str)

# %%
# split_string = []
# for name in df['City']:    
#    name = name.replace(' ',',').replace('(',',')
#    split_string.append(name.split(',',1))

# print(split_string)
split_string = []
for name in df['City']:
    name = name.split('(')[0].strip().strip(')').title()
    split_string.append(name)
df['City'] = split_string
print(df['City'])
# Out:
# 0                      Papri
# 1         Talegaon Dhamdhere
# 2         Talegaon Dhamdhere
# 3                      Oture
# 4                   Nandgaon
#                  ...
# 188690                Sawara
# 188691                Sawara
# 188692                Sawara
# 188693              Jamnagar
# 188694            A/P.Bhokar
# Name: City, Length: 188695, dtype: object

# %%
df.head(5)
# Out:
#      Inv_Date   Prod_Code  QtyInMt  BasicTurnoverInLacs  Customer  \
# 0  01.04.2020  ABCD101001     27.0              6.27426  ABCD1734
# 1  01.04.2020  ABCD103001     12.0              2.96004  ABCD1503
# 2  01.04.2020  ABCD101001     10.0              2.32380  ABCD1503
# 3  01.04.2020  ABCD103001     13.0              3.20671  ABCD1537
# 4  01.04.2020  ABCD103001     13.0              3.20671  ABCD1419
#
#       Material_Desc                City    Taluka District        State
# 0  ABC Nutrition 12               Papri     Mohol  Solapur  Maharashtra
# 1  ABC Nutrition 21  Talegaon Dhamdhere    Shirur     Pune  Maharashtra
# 2  ABC Nutrition 12  Talegaon Dhamdhere    Shirur     Pune  Maharashtra
# 3  ABC Nutrition 21               Oture    Junner     Pune  Maharashtra
# 4  ABC Nutrition 21            Nandgaon  Nandgaon   Nashik  Maharashtra

# %%
df['Material_Desc'] = df['Material_Desc'].astype(str)

# %%
material_code = []
for material in df['Material_Desc']:
    material_code.append(pd.to_numeric(material[-2:]))
df['Material_Desc'] = material_code

# %%
product_code = []
for product in df['Prod_Code']:
    product_code.append(pd.to_numeric(product[4:]))
df['Prod_Code'] = product_code

# %%
customer_code = []
for customer in df['Customer']:
    customer_code.append(pd.to_numeric(customer[4:]))
df['Customer'] = customer_code

# %%
df.head(5)
# Out:
#      Inv_Date  Prod_Code  QtyInMt  BasicTurnoverInLacs  Customer  \
# 0  01.04.2020     101001     27.0              6.27426      1734
# 1  01.04.2020     103001     12.0              2.96004      1503
# 2  01.04.2020     101001     10.0              2.32380      1503
# 3  01.04.2020     103001     13.0              3.20671      1537
# 4  01.04.2020     103001     13.0              3.20671      1419
#
#    Material_Desc                City    Taluka District        State
# 0             12               Papri     Mohol  Solapur  Maharashtra
# 1             21  Talegaon Dhamdhere    Shirur     Pune  Maharashtra
# 2             12  Talegaon Dhamdhere    Shirur     Pune  Maharashtra
# 3             21               Oture    Junner     Pune  Maharashtra
# 4             21            Nandgaon  Nandgaon   Nashik  Maharashtra

# %%
dates = []
for date in df['Inv_Date']:
    dates.append(date.replace('.','-'))
df['Inv_Date'] = dates
df['Inv_Date'] = pd.to_datetime(df['Inv_Date'],format = '%d-%m-%Y')

# %%
df['Inv_Date']
# Out:
# 0        2020-04-01
# 1        2020-04-01
# 2        2020-04-01
# 3        2020-04-01
# 4        2020-04-01
#             ...
# 188690   2023-02-23
# 188691   2023-02-23
# 188692   2023-02-23
# 188693   2023-02-27
# 188694   2023-02-27
# Name: Inv_Date, Length: 188695, dtype: datetime64[ns]

# %%
df['Day'] = pd.DatetimeIndex(df['Inv_Date']).day
df['Year'] = pd.DatetimeIndex(df['Inv_Date']).year
df['Month'] = pd.DatetimeIndex(df['Inv_Date']).month

# %%
def calculate_price(num1: float, num2: float) -> float:
    if(num1==0):
        return 0
    return (num2/num1)*100000
    
df.PerUnitPrice = df.apply(lambda df: calculate_price(num1 = df['QtyInMt'], num2 = df['BasicTurnoverInLacs']), axis=1)
print(df.PerUnitPrice)
# Out:
# 0         23238.000000
# 1         24667.000000
# 2         23238.000000
# 3         24667.000000
# 4         24667.000000
#               ...
# 188690    24762.000000
# 188691    41666.666667
# 188692    24761.888889
# 188693    32380.954545
# 188694    25714.280000
# Length: 188695, dtype: float64

# %%
df.head(5)
# Out:
#     Inv_Date  Prod_Code  QtyInMt  BasicTurnoverInLacs  Customer  \
# 0 2020-04-01     101001     27.0              6.27426      1734
# 1 2020-04-01     103001     12.0              2.96004      1503
# 2 2020-04-01     101001     10.0              2.32380      1503
# 3 2020-04-01     103001     13.0              3.20671      1537
# 4 2020-04-01     103001     13.0              3.20671      1419
#
#    Material_Desc                City    Taluka District        State  Day  \
# 0             12               Papri     Mohol  Solapur  Maharashtra    1
# 1             21  Talegaon Dhamdhere    Shirur     Pune  Maharashtra    1
# 2             12  Talegaon Dhamdhere    Shirur     Pune  Maharashtra    1
# 3             21               Oture    Junner     Pune  Maharashtra    1
# 4             21            Nandgaon  Nandgaon   Nashik  Maharashtra    1
#
#    Year  Month
# 0  2020      4
# 1  2020      4
# 2  2020      4
# 3  2020      4
# 4  2020      4

# %% [markdown]
# # Data Visulization

# %%
import pywedge as pw
x = pw.Pywedge_Charts(df,c=None,y="BasicTurnoverInLacs")
charts = x.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %%
maha = df[df['State']=='Maharashtra']
maha.head()
# Out:
#     Inv_Date  Prod_Code  QtyInMt  BasicTurnoverInLacs  Customer  \
# 0 2020-04-01     101001     27.0              6.27426      1734
# 1 2020-04-01     103001     12.0              2.96004      1503
# 2 2020-04-01     101001     10.0              2.32380      1503
# 3 2020-04-01     103001     13.0              3.20671      1537
# 4 2020-04-01     103001     13.0              3.20671      1419
#
#    Material_Desc                City    Taluka District        State  Day  \
# 0             12               Papri     Mohol  Solapur  Maharashtra    1
# 1             21  Talegaon Dhamdhere    Shirur     Pune  Maharashtra    1
# 2             12  Talegaon Dhamdhere    Shirur     Pune  Maharashtra    1
# 3             21               Oture    Junner     Pune  Maharashtra    1
# 4             21            Nandgaon  Nandgaon   Nashik  Maharashtra    1
#
#    Year  Month
# 0  2020      4
# 1  2020      4
# 2  2020      4
# 3  2020      4
# 4  2020      4

# %%
mat = df[df['Material_Desc']==12]
mat = mat[['Month','BasicTurnoverInLacs']]
mat = mat.groupby(['Month'],as_index=False)['BasicTurnoverInLacs'].sum()
mat.columns = ['ds', 'y'] 
mat.head(5)
# Out:
#    ds            y
# 0   1  12333.15478
# 1   2  11466.35342
# 2   3   5342.83700
# 3   4  11086.68849
# 4   5  12081.52121

# %%
plt.scatter(maha['Inv_Date'], maha['BasicTurnoverInLacs'], color='red')
plt.title('Time Vs BasicTurnoverInLacs', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.ylabel('BasicTurnoverInLacs', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.plot(maha['Inv_Date'],maha['BasicTurnoverInLacs'])
plt.show()

# %%
data = maha[['Inv_Date','BasicTurnoverInLacs']]
data.dropna(inplace=True)
data.head()
# Out:
#     Inv_Date  BasicTurnoverInLacs
# 0 2020-04-01              6.27426
# 1 2020-04-01              2.96004
# 2 2020-04-01              2.32380
# 3 2020-04-01              3.20671
# 4 2020-04-01              3.20671

# %%
data.columns = ['ds', 'y'] 
data
# Out:
#                ds        y
# 0      2020-04-01  6.27426
# 1      2020-04-01  2.96004
# 2      2020-04-01  2.32380
# 3      2020-04-01  3.20671
# 4      2020-04-01  3.20671
# ...           ...      ...
# 188689 2023-02-23 -8.52381
# 188690 2023-02-23 -1.23810
# 188691 2023-02-23 -6.25000
# 188692 2023-02-23 -2.22857
# 188694 2023-02-27 -6.42857
#
# [135950 rows x 2 columns]

# %%
upd_data = data.groupby(['ds'],as_index=False)['y'].sum()
upd_data
# Out:
#              ds          y
# 0    2020-04-01   22.36483
# 1    2020-04-02   72.16297
# 2    2020-04-03   50.73437
# 3    2020-04-04  123.79442
# 4    2020-04-05  166.46900
# ...         ...        ...
# 1057 2023-02-25  599.23821
# 1058 2023-02-26  459.49287
# 1059 2023-02-27  666.40687
# 1060 2023-02-28  868.24671
# 1061 2023-03-09    3.20000
#
# [1062 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.xlabel('year', fontsize=12)
plt.ylabel('BasicTurnoverInLacs',fontsize=12)
plt.plot(upd_data['ds'],upd_data['y'])
plt.show()

# %% [markdown]
# # Data Model

# %%
conda install neuralprophet
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::scrapy==2.8.0=py310hecd8cb5_0
#   - defaults/osx-64::parsel==1.6.0=py310hecd8cb5_0
#   - defaults/noarch::itemloaders==1.0.4=pyhd3eb1b0_1
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/saifuddinshaikh/anaconda3
#
#   added / updated specs:
#     - neuralprophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.05.30 |       hecd8cb5_0         121 KB
#     certifi-2023.5.7           |  py310hecd8cb5_0         153 KB
#     ------------------------------------------------------------
#                                            Total:         274 KB
#
# The following NEW packages will be INSTALLED:
#
#   cssselect          pkgs/main/noarch::cssselect-1.1.0-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-hecd8cb5_0 --> 2023.05.30-hecd8cb5_0
#   certifi                         2022.12.7-py310hecd8cb5_0 --> 2023.5.7-py310hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2023 | 121 KB    |                                       |   0%
# certifi-2023.5.7     | 153 KB    |                                       |   0%
# ca-certificates-2023 | 121 KB    | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Train Model using Prophet

# %%
m = NeuralProphet()

# %%
model = m.fit(upd_data, freq='D')
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.623% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 190
#   0%|          | 0/126 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.14E+00, min: 1.32E-01
#   0%|          | 0/126 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.34E+00, min: 1.32E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.35E-01
# Epoch[190/190]: 100%|█| 190/190 [00:06<00:00, 28.01it/s, SmoothL1Loss=0.0294, MA

# %%
future = m.make_future_dataframe(upd_data, periods=900,n_historic_predictions=True)
forecast = m.predict(future)
forecast.head()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.623% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.796% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.796% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#           ds          y   residual1       yhat1       trend  season_yearly  \
# 0 2020-04-01   22.36483  206.436699  228.801529  154.956940      48.738834
# 1 2020-04-02   72.16297  116.412637  188.575607  154.480865      48.777363
# 2 2020-04-03   50.73437  196.549245  247.283615  154.004807      48.442844
# 3 2020-04-04  123.79442   97.399260  221.193680  153.528748      47.737736
# 4 2020-04-05  166.46900  -61.148848  105.320152  153.052689      46.668781
#
#    season_weekly
# 0      25.105759
# 1     -14.682627
# 2      44.835976
# 3      19.927202
# 4     -94.401314

# %% [markdown]
# # Forecast Basic Turnover

# %%
plot1 = m.plot(forecast)

# %%
 plot2 = m.plot_components(forecast)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
cutoff_date = upd_data['ds'].min() + pd.DateOffset(years=2)

# %%
# Split the data into training and testing sets
train_df = upd_data[upd_data['ds'] < cutoff_date]
test_df = upd_data[upd_data['ds'] >= cutoff_date]

# %%
train_df.shape
# Out:
# (730, 2)

# %%
test_df.shape
# Out:
# (332, 2)

# %%
# Initialize the NeuralProphet model
model = NeuralProphet()

# Fit the model to the training data
model.fit(train_df)

# Perform forecasting on the test data
future = model.make_future_dataframe(test_df, periods=len(test_df))
forecast = model.predict(future)
forecast

# Calculate the accuracy of the forecasted data
# accuracy = model.loss(test_df['y'], forecast['yhat'])
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.863% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 215
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.06E-01, min: 2.49E-01
#   0%|          | 0/122 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.64E+00, min: 2.10E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 2.59E-01
# Epoch[215/215]: 100%|█| 215/215 [00:09<00:00, 23.43it/s, SmoothL1Loss=0.0362, MA
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.096% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.699% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.699% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
#             ds     y residual1       yhat1       trend  season_weekly
# 0   2023-03-10  None      None  174.669403  147.583099      27.086306
# 1   2023-03-11  None      None  153.684128  147.369629       6.314499
# 2   2023-03-12  None      None   53.741142  147.156128     -93.414986
# 3   2023-03-13  None      None  177.674103  146.942642      30.731457
# 4   2023-03-14  None      None  161.386627  146.729156      14.657475
# ..         ...   ...       ...         ...         ...            ...
# 327 2024-01-31  None      None  106.473053   77.772438      28.700621
# 328 2024-02-01  None      None   63.483562   77.558937     -14.075377
# 329 2024-02-02  None      None  104.431778   77.345467      27.086306
# 330 2024-02-03  None      None   83.446465   77.131966       6.314499
# 331 2024-02-04  None      None  -16.496494   76.918495     -93.414986
#
# [332 rows x 6 columns]

# %%
forecast['yhat1'].shape
# Out:
# (332,)

# %%
test_df['y'].shape
# Out:
# (332,)

# %%
accuracy = 
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 accuracy = accuracy_score(test_df['y'],forecast['yhat1'])
#       2 print(accuracy)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
#     200         f"parameter of {func.__qualname__} must be",
#     201         str(e),
#     202     )
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:221, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     155 """Accuracy classification score.
#     156
#     157 In multilabel classification, this function computes subset accuracy:
#    (...)
#     217 0.5
#     218 """
#     220 # Compute accuracy for each possible representation
# --> 221 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222 check_consistent_length(y_true, y_pred, sample_weight)
#     223 if y_type.startswith("multilabel"):
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:106, in _check_targets(y_true, y_pred)
#     104 # No metrics support "multiclass-multioutput" format
#     105 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 106     raise ValueError("{0} is not supported".format(y_type))
#     108 if y_type in ["binary", "multiclass"]:
#     109     y_true = column_or_1d(y_true)
#
# ValueError: continuous is not supported

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Calculate MAE and RMSE
mae = mean_absolute_error(test_df['y'], forecast['yhat1'].values)
rmse = mean_squared_error(test_df['y'], forecast['yhat1'].values, squared=False)

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 1127.5281672829426
# RMSE: 1173.0472272239517

# %%
# Set the threshold or tolerance level
threshold = 0.05  # 5% tolerance

# Calculate the absolute percentage error
absolute_percentage_error = abs((test_df['y'] - forecast['yhat1'].values) / test_df['y'])

# Calculate the percentage accuracy
percentage_accuracy = 100 * (1 - absolute_percentage_error.mean())

print("Percentage Accuracy:", percentage_accuracy)
# Out:
# Percentage Accuracy: -949.0069084820454

# %%
m2 = NeuralProphet()

# %%
model2 = m2.fit(mat, freq='D')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:289, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string 1 not likely a datetime
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "1" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 model2 = m2.fit(mat, freq='D')
#
# File ~/anaconda3/lib/python3.10/site-packages/neuralprophet/forecaster.py:700, in NeuralProphet.fit(self, df, freq, validation_df, progress, minimal)
#     695     self.predict_steps = 1
#     696     log.warning(
#     697         "Changing n_forecasts to 1. Without lags, the forecast can be "
#     698         "computed for any future time, independent of lagged values"
#     699     )
# --> 700 df = self._check_dataframe(df, check_y=True, exogenous=True)
#     701 self.data_freq = df_utils.infer_frequency(df, n_lags=self.max_lags, freq=freq)
#     702 df = self._handle_missing_data(df, freq=self.data_freq)
#
# File ~/anaconda3/lib/python3.10/site-packages/neuralprophet/forecaster.py:2155, in NeuralProphet._check_dataframe(self, df, check_y, exogenous)
#    2132 """Performs basic data sanity checks and ordering
#    2133
#    2134 Prepare dataframe for fitting or predicting.
#    (...)
#    2152         checked dataframe
#    2153 """
#    2154 df, _, _, _, _ = df_utils.prep_or_copy_df(df)
# -> 2155 df, regressors_to_remove = df_utils.check_dataframe(
#    2156     df=df,
#    2157     check_y=check_y,
#    2158     covariates=self.config_lagged_regressors if exogenous else None,
#    2159     regressors=self.config_regressors if exogenous else None,
#    2160     events=self.config_events if exogenous else None,
#    2161 )
#    2162 for reg in regressors_to_remove:
#    2163     log.warning(f"Removing regressor {reg} because it is not present in the data.")
#
# File ~/anaconda3/lib/python3.10/site-packages/neuralprophet/df_utils.py:519, in check_dataframe(df, check_y, covariates, regressors, events)
#     517 regressors_to_remove = []
#     518 for df_name, df_i in df.groupby("ID"):
# --> 519     df_aux, reg = check_single_dataframe(df_i, check_y, covariates, regressors, events)
#     520     df_aux = df_aux.copy(deep=True)
#     521     if len(reg) > 0:
#
# File ~/anaconda3/lib/python3.10/site-packages/neuralprophet/df_utils.py:441, in check_single_dataframe(df, check_y, covariates, regressors, events)
#     439     df["ds"] = df.loc[:, "ds"].astype(str)
#     440 if not np.issubdtype(df["ds"].dtype, np.datetime64):
# --> 441     df["ds"] = pd.to_datetime(df.loc[:, "ds"])
#     442 if df["ds"].dt.tz is not None:
#     443     raise ValueError("Column ds has timezone specified, which is not supported. Remove timezone.")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:289, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string 1 not likely a datetime present at position 0

# %%
blm = pw.baseline_model(train, test, c='None', df.groupby(['Day']).sum()['QtyInMt'], 'Regression')
blm.classification_summary()
# Out:
#   Cell In[193], line 1
#     blm = pw.baseline_model(train, test, c='None', df.groupby(['Day']).sum()['QtyInMt'], 'Regression')
#                                                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
month_names = df['Month']
months = {
        'jan': 1,
        'feb': 2,
        'mar': 3,
        'apr':4,
         'may':5,
         'jun':6,
         'jul':7,
         'aug':8,
         'sep':9,
         'oct':10,
         'nov':11,
         'dec':12
        }
month_numeric_list = []
for name in month_names:
    short_name = name.strip()[:3].lower()
    if(short_name in months):
        month_numeric_list.append(months[short_name])
# print(month_numeric_list)

# %%
# !pip install pyxlsb
# Out:
# Requirement already satisfied: pyxlsb in ./anaconda3/lib/python3.10/site-packages (1.0.10)

# %%
df.max()
# Out:
# FY                                 2020-21
# Inv_Date               2021-03-31 00:00:00
# Prod_Code                       ABCD305002
# Material_Desc              ABC Nutrition 6
# QtyInMt                               98.0
# BasicTurnoverInLacs               23.89338
# PerUnitPrice                       23238.0
# Customer                          ABCD4402
# UOM                                     MT
# Customer_Name               not to be used
# City                                 Yevla
# Taluka                            Zagadiya
# District                          Yavatmal
# State                        Uttar pradesh
# Day                                     31
# Month                                  Sep
# dtype: object

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(df['State'],df.index,color='maroon',width = 0.8)
plt.xlabel('State')
plt.ylabel('Production')
plt.show()

# %%
df['State'].value_counts()
# Out:
# Maharashtra       52751
# Karnataka          7466
# Gujarat            3337
# Andhra pradesh     2425
# Telangana          1103
# Madhya pradesh      897
# Tamil nadu          280
# Uttar pradesh       278
# Punjab              160
# Haryana              81
# Chhattisgarh         72
# Rajasthan            39
# Name: State, dtype: int64

# %%
# !pip install pywedge
# Out:
# Requirement already satisfied: pywedge in ./anaconda3/lib/python3.10/site-packages (0.5.1.8)
# Requirement already satisfied: scikit-learn in ./anaconda3/lib/python3.10/site-packages (from pywedge) (1.2.1)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from pywedge) (4.64.1)
# Requirement already satisfied: xgboost in ./anaconda3/lib/python3.10/site-packages (from pywedge) (1.7.5)
# Requirement already satisfied: imbalanced-learn in ./anaconda3/lib/python3.10/site-packages (from pywedge) (0.10.1)
# Requirement already satisfied: plotly in ./anaconda3/lib/python3.10/site-packages (from pywedge) (5.9.0)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.10/site-packages (from pywedge) (1.5.3)
# Requirement already satisfied: ipywidgets in ./anaconda3/lib/python3.10/site-packages (from pywedge) (7.6.5)
# Requirement already satisfied: numpy in ./anaconda3/lib/python3.10/site-packages (from pywedge) (1.23.5)
# Requirement already satisfied: catboost>0.24 in ./anaconda3/lib/python3.10/site-packages (from pywedge) (1.1.1)
# Requirement already satisfied: six in ./anaconda3/lib/python3.10/site-packages (from catboost>0.24->pywedge) (1.16.0)
# Requirement already satisfied: scipy in ./anaconda3/lib/python3.10/site-packages (from catboost>0.24->pywedge) (1.10.0)
# Requirement already satisfied: matplotlib in ./anaconda3/lib/python3.10/site-packages (from catboost>0.24->pywedge) (3.7.0)
# Requirement already satisfied: graphviz in ./anaconda3/lib/python3.10/site-packages (from catboost>0.24->pywedge) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./anaconda3/lib/python3.10/site-packages (from pandas->pywedge) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.10/site-packages (from pandas->pywedge) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->pywedge) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./anaconda3/lib/python3.10/site-packages (from imbalanced-learn->pywedge) (2.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (0.2.0)
# Requirement already satisfied: ipython>=4.0.0 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (8.10.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (5.7.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in ./anaconda3/lib/python3.10/site-packages (from ipywidgets->pywedge) (6.19.2)
# Requirement already satisfied: tenacity>=6.2.0 in ./anaconda3/lib/python3.10/site-packages (from plotly->pywedge) (8.0.1)
# Requirement already satisfied: nest-asyncio in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (7.3.4)
# Requirement already satisfied: comm>=0.1.1 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (0.1.2)
# Requirement already satisfied: appnope in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (6.1)
# Requirement already satisfied: psutil in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (0.1.6)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->pywedge) (22.0)
# Requirement already satisfied: jedi>=0.16 in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.18.1)
# Requirement already satisfied: stack-data in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.2.0)
# Requirement already satisfied: pickleshare in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (4.8.0)
# Requirement already satisfied: backcall in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (0.2.0)
# Requirement already satisfied: decorator in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (2.11.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in ./anaconda3/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->pywedge) (3.0.36)
# Requirement already satisfied: jsonschema>=2.6 in ./anaconda3/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets->pywedge) (4.17.3)
# Requirement already satisfied: fastjsonschema in ./anaconda3/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets->pywedge) (2.16.2)
# Requirement already satisfied: jupyter-core in ./anaconda3/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets->pywedge) (5.2.0)
# Requirement already satisfied: notebook>=4.4.1 in ./anaconda3/lib/python3.10/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pywedge) (6.5.2)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from matplotlib->catboost>0.24->pywedge) (1.0.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in ./anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->pywedge) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./anaconda3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pywedge) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in ./anaconda3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pywedge) (22.1.0)
# Requirement already satisfied: entrypoints in ./anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pywedge) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in ./anaconda3/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->pywedge) (2.5.2)
# Requirement already satisfied: prometheus-client in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (6.5.4)
# Requirement already satisfied: argon2-cffi in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (21.3.0)
# Requirement already satisfied: jinja2 in ./anaconda3/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (3.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->pywedge) (0.7.0)
# Requirement already satisfied: wcwidth in ./anaconda3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets->pywedge) (0.2.5)
# Requirement already satisfied: executing in ./anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pywedge) (0.8.3)
# Requirement already satisfied: pure-eval in ./anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pywedge) (0.2.2)
# Requirement already satisfied: asttokens in ./anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->pywedge) (2.0.5)
# Requirement already satisfied: jupyter-server>=1.8 in ./anaconda3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in ./anaconda3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.2.2)
# Requirement already satisfied: bleach in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (4.1.0)
# Requirement already satisfied: lxml in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (4.9.1)
# Requirement already satisfied: tinycss2 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (2.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.1.2)
# Requirement already satisfied: defusedxml in ./anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.7.1)
# Requirement already satisfied: argon2-cffi-bindings in ./anaconda3/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in ./anaconda3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (3.5.0)
# Requirement already satisfied: websocket-client in ./anaconda3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in ./anaconda3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (2.3.2.post1)
# Requirement already satisfied: webencodings in ./anaconda3/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (0.5.1)
# Requirement already satisfied: idna>=2.8 in ./anaconda3/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (3.4)
# Requirement already satisfied: sniffio>=1.1 in ./anaconda3/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (1.2.0)
# Requirement already satisfied: pycparser in ./anaconda3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pywedge) (2.21)

# %%
df.head(3)
# Out:
#         FY   Inv_Date   Prod_Code     Material_Desc  QtyInMt  \
# 0  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     27.0
# 1  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     12.0
# 2  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     10.0
#
#    BasicTurnoverInLacs  PerUnitPrice  Customer UOM  \
# 0              6.27426       23238.0  ABCD1734  MT
# 1              2.96004           NaN  ABCD1503  MT
# 2              2.32380           NaN  ABCD1503  MT
#
#                  Customer_Name                City  Taluka District  \
# 0          KISAN AGRO SERVICES               Papri   Mohol  Solapur
# 1  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere  Shirur     Pune
# 2  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere  Shirur     Pune
#
#          State  Day Month
# 0  Maharashtra    1   Apr
# 1  Maharashtra    1   Apr
# 2  Maharashtra    1   Apr

# %%
df.head(5)
# Out:
#         FY   Inv_Date   Prod_Code     Material_Desc  QtyInMt  \
# 0  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     27.0
# 1  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     12.0
# 2  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     10.0
# 3  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     13.0
# 4  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     13.0
#
#    BasicTurnoverInLacs  PerUnitPrice  Customer UOM  \
# 0              6.27426       23238.0  ABCD1734  MT
# 1              2.96004       24667.0  ABCD1503  MT
# 2              2.32380       23238.0  ABCD1503  MT
# 3              3.20671       24667.0  ABCD1537  MT
# 4              3.20671       24667.0  ABCD1419  MT
#
#                  Customer_Name                City    Taluka District  \
# 0          KISAN AGRO SERVICES               Papri     Mohol  Solapur
# 1  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere    Shirur     Pune
# 2  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere    Shirur     Pune
# 3      CHAITANYA AGREE TRADERS               Oture    Junner     Pune
# 4     KAMAL KRISHI SEVA KENDRA            Nandgaon  Nandgaon   Nashik
#
#          State  Day Month
# 0  Maharashtra    1   Apr
# 1  Maharashtra    1   Apr
# 2  Maharashtra    1   Apr
# 3  Maharashtra    1   Apr
# 4  Maharashtra    1   Apr

# %%
import random
import matplotlib.colors as mcolors
color_choice = random.choices(list(mcolors.CSS4_COLORS.values()),k = 25)

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

# fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
df.groupby('Material_Desc').size().plot(kind='pie', autopct='%1.0f%%', textprops={'fontsize': 10},
                                  colors= color_choice, radius = 1.4)
plt.legend(labels=df.Material_Desc, loc='upper center', 
           bbox_to_anchor=(0.5, -0.2), ncol=2)

# %%
a = []
for i in range(1,26):
    a.append(i)
nutrition_feed_type = {'Cattle': a[0:7],'Poultry': a[7:12],'Swine': a[12:15],'Aqua': a[15:20], 'DomesticatedAnimal': a[20:25]}
# for feed in nutrition_feed_type:
#     print("feed: ",feed,end='\n')
#     for i in nutrition_feed_type[feed]:
#         for material in df['Material_Desc']:
#            if(material[-2:].astype(int) == i):
#                df[]
#           b = [material for material in df['Material_Desc'] if (material[-2:].astype(int)==i)]
#           print(b)
# print(df['Material_Desc'].value_counts())
# print(df['FeedType'].value_counts())
b = []
for material in df['Material_Desc']:
     for feed in nutrition_feed_type:
        if(pd.to_numeric(material[-2:]) in nutrition_feed_type[feed]):
           b.append(feed)
           break
df['FeedType'] = b
# pivot_table = pd.pivot_table(df,index=['FeedType','Material_Desc'],values = 'BasicTurnoverInLacs')
variable = df.groupby(['FeedType','Material_Desc']).sum()
sales_per_day = df.groupby(['Month','Day'])['BasicTurnoverInLacs'].sum()
sales_per_day
# variable
# pivot_table
# Out:
# Month  Day
# Apr    1       22.36483
#        2       72.16297
#        3       50.73437
#        4      123.79442
#        5      174.26134
#                 ...
# Sep    26     945.21130
#        27     519.45917
#        28     405.12719
#        29     531.71082
#        30     800.09863
# Name: BasicTurnoverInLacs, Length: 365, dtype: float64

# %%
df.groupby(['Month']).sum()['BasicTurnoverInLacs'].plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %%
df.groupby(['Month']).sum()['BasicTurnoverInLacs'].plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

# fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
df.groupby(['FeedType']).sum()['BasicTurnoverInLacs'].plot(kind='pie', autopct='%1.0f%%', textprops={'fontsize': 10},
                                  colors= color_choice, radius = 1.3)
plt.legend(labels=df.FeedType, loc='upper center', 
           bbox_to_anchor=(0.5, -0.3), ncol=2)

# %%
# color_pal = sns.color_palette()
df['FeedType'].value_counts()
# Out:
# DomesticatedAnimal    34721
# Poultry               20393
# Cattle                 7873
# Aqua                   5546
# Swine                   356
# Name: FeedType, dtype: int64

# %%
df.groupby(['State']).sum()['BasicTurnoverInLacs'].plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
# data_chart = pd.DataFrame(df.groupby(['State','District']).sum())
# data_chart
df.groupby(['State','District']).sum()['BasicTurnoverInLacs'].plot(kind='line')
# Out:
# <Axes: xlabel='State,District'>

# %%
import pywedge as pw
x = pw.Pywedge_Charts(df,c=None,y="BasicTurnoverInLacs")
charts = x.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %%
data = df.groupby(['Day']).sum()['QtyInMt']
data
# Out:
# Day
# 1     21019.350
# 2     21174.350
# 3     19586.450
# 4     20669.500
# 5     21097.600
# 6     25510.550
# 7     19975.000
# 8     25853.400
# 9     25598.600
# 10    21018.700
# 11    22126.350
# 12    25228.700
# 13    23352.350
# 14    23545.450
# 15    24375.250
# 16    19735.450
# 17    31419.295
# 18    27067.800
# 19    24824.700
# 20    20122.800
# 21    22855.100
# 22    30220.800
# 23    28009.500
# 24    26861.500
# 25    36731.650
# 26    36002.500
# 27    35900.850
# 28    27357.200
# 29    31070.000
# 30    40763.210
# 31    30944.900
# Name: QtyInMt, dtype: float64

# %%
df.head(5)
# Out:
#         FY   Inv_Date   Prod_Code     Material_Desc  QtyInMt  \
# 0  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     27.0
# 1  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     12.0
# 2  2020-21 2020-04-01  ABCD101001  ABC Nutrition 12     10.0
# 3  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     13.0
# 4  2020-21 2020-04-01  ABCD103001  ABC Nutrition 21     13.0
#
#    BasicTurnoverInLacs  PerUnitPrice  Customer UOM  \
# 0              6.27426       23238.0  ABCD1734  MT
# 1              2.96004       24667.0  ABCD1503  MT
# 2              2.32380       23238.0  ABCD1503  MT
# 3              3.20671       24667.0  ABCD1537  MT
# 4              3.20671       24667.0  ABCD1419  MT
#
#                  Customer_Name                City    Taluka District  \
# 0          KISAN AGRO SERVICES               Papri     Mohol  Solapur
# 1  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere    Shirur     Pune
# 2  SHRINATH KRUSHI SEVA KENDRA  Talegaon Dhamdhere    Shirur     Pune
# 3      CHAITANYA AGREE TRADERS               Oture    Junner     Pune
# 4     KAMAL KRISHI SEVA KENDRA            Nandgaon  Nandgaon   Nashik
#
#          State  Day Month            FeedType
# 0  Maharashtra    1   Apr             Poultry
# 1  Maharashtra    1   Apr  DomesticatedAnimal
# 2  Maharashtra    1   Apr             Poultry
# 3  Maharashtra    1   Apr  DomesticatedAnimal
# 4  Maharashtra    1   Apr  DomesticatedAnimal
